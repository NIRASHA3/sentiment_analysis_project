# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json','r') as file:
    data=json.load(file)

# %%
data
# Out:
# {'username': 'nirashadeshani', 'key': 'f12cbc6c26083ea93b46bdb83def4802'}

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in d:\sentiment_analysis_project\env\Lib\site-packages (2.0.0)
# Requirement already satisfied: bleach in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (0.1.16)
# Requirement already satisfied: packaging in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (26.0)
# Requirement already satisfied: protobuf in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (7.34.1)
# Requirement already satisfied: python-dateutil in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (2.33.1)
# Requirement already satisfied: tqdm in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in d:\sentiment_analysis_project\env\Lib\site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: webencodings in d:\sentiment_analysis_project\env\Lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in d:\sentiment_analysis_project\env\Lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in d:\sentiment_analysis_project\env\Lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\sentiment_analysis_project\env\Lib\site-packages (from requests->kaggle) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\sentiment_analysis_project\env\Lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in d:\sentiment_analysis_project\env\Lib\site-packages (from requests->kaggle) (2026.2.25)
# Requirement already satisfied: colorama in d:\sentiment_analysis_project\env\Lib\site-packages (from tqdm->kaggle) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
